# %% [markdown]
# Este notebook está sendo utilizado para investigar o estado dos dados e processá-los, a fim de realizar posteriormente uma análise exploratória dos dados e em seguida treinar um modelo de machine learning para prever se uma ação está barata, cara ou se encontra em um ponto neutro baseando nos dados dos indicadores financeiros da empresa.
#
# Este notebook servirá como base para criar um procedimento que será utilizado para todos os tickers, consolidando os dados em um único arquivo. Esse processo estará no arquivo .py (src/data_processing/processor.py) que automatizará essa tarefa.

# %%
# Importar bibliotecas
import pandas as pd
import numpy as np
import yfinance as yf
import os

# %%
#Define um ticker para processar os dados
ticker = "VALE3"

#Intervalo de data para buscar os preços da ação no Yahoo Finance
start_date = '2007-01-01'
end_date = '2024-01-01'

# Carregar dados
data = pd.read_csv(f"../../data/raw/indicadores_{ticker}.csv")

# Baixar os dados do Yahoo Finance
precos = yf.download((ticker+'.SA'), start=start_date, end=end_date, interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#           Tipo do Indicador Nome do Indicador   ATUAL   2023   2022    2021  \
# 0  INDICADORES DE VALUATION               D.Y  11,75%  7,87%  8,53%  18,79%
# 1  INDICADORES DE VALUATION               P/L    5,68   7,37   4,43    3,30
# 2  INDICADORES DE VALUATION         PEG RATIO   -0,10  -0,13      -       -
# 3  INDICADORES DE VALUATION              P/VP    1,42   1,84   2,27    2,08
# 4  INDICADORES DE VALUATION         EV/EBITDA    4,04   5,05   4,06    2,70
#
#     2020    2019   2018   2017   2016   2015    2014      2013   2012   2011  \
# 0  2,75%   2,65%  3,86%  3,29%  0,65%  7,49%   8,63%     5,06%  5,35%  7,31%
# 1  17,30  -42,22  10,50  11,98  10,12  -1,55  123,17  1.664,73  22,93   5,60
# 2      -       -   0,23   0,37  -0,08   0,00    0,17    -16,84  -0,31      -
# 3   2,49    1,74   1,58   1,47   1,06   0,52    0,80      1,29   1,51   1,48
# 4   6,34   15,85      -      -      -      -       -         -      -      -
#
#   2010 2009 2008
# 0   -%   -%   -%
# 1    -    -    -
# 2    -    -    -
# 3    -    -    -
# 4    -    -    -

# %% [markdown]
# - O arquivo atualmente apresenta uma estrutura onde cada ano é representado por uma coluna, porém, precisamos reorganizar para que os anos sejam representados em linhas.
#
# - Além disso, os valores numéricos estão formatados com caracteres especiais, como por exemplo "11,75%", e será necessário ajustá-los para o formato padrão, como "11.75".
#
# - Por fim, em vez de utilizar o caractere "-" para representar valores nulos, precisaremos substituí-lo por "null", e remover a coluna "Tipo do Indicador". Também será necessário renomear a coluna atual para "2024".

# %%
precos_df = pd.DataFrame(precos)

precos_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2007-01-01  31.850000  32.700001  29.100000  29.299999  12.824647  11537400
# 2007-01-08  29.500000  31.870001  29.004999  31.799999  13.918905  10284800
# 2007-01-15  31.900000  32.369999  30.850000  32.360001  14.164014   9608800
# 2007-01-22  32.450001  35.799999  32.375000  35.200001  15.407085   9828600
# 2007-01-29  35.375000  36.404999  34.275002  35.599998  15.582168   9328800

# %%
# Função para calcular a média do preço de fechamento para um determinado ano
def close_price_mean_for_year(df, year):
    df_year = df[df.index.year == year]
    return df_year['Close'].mean()

# %%
# Remover a coluna "Tipo do Indicador"
data = data.drop('Tipo do Indicador', axis=1)

# Renomear a coluna "ATUAL" para "2024"
data = data.rename(columns={'ATUAL': '2024'})

# %%
df = pd.DataFrame(data)

# Remover caracteres especiais e ajustar o separador decimal
for col in df.columns[1:]:
    df[col] = df[col].str.replace(",", ".").str.rstrip("%")


# Substituir '-' por null em todas as colunas exceto as duas primeiras
df.iloc[:, 1:] = df.iloc[:, 1:].replace('-', np.nan)

# %%
# Converter as colunas para tipo numérico
for col in df.columns[1:]:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df.head()
# Out:
#   Nome do Indicador   2024  2023  2022   2021   2020   2019   2018   2017  \
# 0               D.Y  11.75  7.87  8.53  18.79   2.75   2.65   3.86   3.29
# 1               P/L   5.68  7.37  4.43   3.30  17.30 -42.22  10.50  11.98
# 2         PEG RATIO  -0.10 -0.13   NaN    NaN    NaN    NaN   0.23   0.37
# 3              P/VP   1.42  1.84  2.27   2.08   2.49   1.74   1.58   1.47
# 4         EV/EBITDA   4.04  5.05  4.06   2.70   6.34  15.85    NaN    NaN
#
#     2016  2015    2014   2013   2012  2011  2010  2009  2008
# 0   0.65  7.49    8.63   5.06   5.35  7.31   NaN   NaN   NaN
# 1  10.12 -1.55  123.17    NaN  22.93  5.60   NaN   NaN   NaN
# 2  -0.08  0.00    0.17 -16.84  -0.31   NaN   NaN   NaN   NaN
# 3   1.06  0.52    0.80   1.29   1.51  1.48   NaN   NaN   NaN
# 4    NaN   NaN     NaN    NaN    NaN   NaN   NaN   NaN   NaN

# %%
# Transpor o DataFrame
df_transposed = df.transpose()

# Resetar o índice
df_transposed = df_transposed.reset_index()

# Definir a primeira linha como o cabeçalho
df_transposed.columns = df_transposed.iloc[0]

# Remover a primeira linha do DataFrame
df_transposed = df_transposed[1:]

# Resetar o índice
df_transposed = df_transposed.reset_index(drop=True)

#Troca o nome da coluna Nome do Indicador para Ano
df_transposed = df_transposed.rename(columns={'Nome do Indicador': 'Ano'})

df_transposed
# Out:
# 0    Ano    D.Y     P/L PEG RATIO  P/VP EV/EBITDA EV/EBIT P/EBITDA  P/EBIT  \
# 0   2024  11.75    5.68      -0.1  1.42      4.04     5.0      3.4    4.21
# 1   2023   7.87    7.37     -0.13  1.84      5.05    6.25     4.42    5.47
# 2   2022   8.53    4.43       NaN  2.27      4.06    5.16      3.7     4.7
# 3   2021  18.79     3.3       NaN  2.08       2.7    2.91     2.63    2.83
# 4   2020   2.75    17.3       NaN  2.49      6.34    9.03     6.23    8.88
# 5   2019   2.65  -42.22       NaN  1.74     15.85  139.25    14.32  125.75
# 6   2018   3.86    10.5      0.23  1.58       NaN    7.11      NaN    6.24
# 7   2017   3.29   11.98      0.37  1.47       NaN    7.85      NaN    6.11
# 8   2016   0.65   10.12     -0.08  1.06       NaN   10.44      NaN     6.5
# 9   2015   7.49   -1.55       0.0  0.52       NaN   -5.83      NaN   -2.39
# 10  2014   8.63  123.17      0.17   0.8       NaN    8.81      NaN    5.64
# 11  2013   5.06     NaN    -16.84  1.29       NaN    7.42      NaN    5.73
# 12  2012   5.35   22.93     -0.31  1.51       NaN   18.25      NaN   14.96
# 13  2011   7.31     5.6       NaN  1.48       NaN    4.79      NaN    4.04
# 14  2010    NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 15  2009    NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 16  2008    NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
#
# 0     VPA  ... M. BRUTA M. EBITDA M. EBIT M. LÍQUIDA    ROE    ROA   ROIC  \
# 0    41.9  ...    40.12     38.45   31.07      23.03  24.99  10.66  21.26
# 1    41.9  ...    40.12     38.45   31.07      23.03  24.99  10.66  21.26
# 2   39.15  ...    45.17     50.73   39.88      42.35  51.27  21.16  28.76
# 3   37.49  ...    60.05     51.84   48.15       41.3  63.01  24.29  42.35
# 4   35.16  ...    52.73     35.57   24.97      12.81  14.38   5.59  18.93
# 5   30.56  ...     43.6     13.24    1.51      -4.49  -4.13   -1.8  -0.12
# 6   32.25  ...    39.62       NaN    32.1      19.08  15.06   7.51  18.07
# 7   27.41  ...    38.03       NaN   31.82      16.24  12.26   5.37  13.45
# 8   24.26  ...    35.39       NaN   21.89      14.07  10.46   4.13   4.86
# 9   25.01  ...    19.57       NaN  -36.67     -56.64 -33.71 -12.79 -19.03
# 10  27.29  ...    34.92       NaN   25.21       1.16   0.65   0.31   7.59
# 11  27.65  ...    48.26       NaN   32.95       0.11   0.08   0.04   8.23
# 12  27.93  ...     45.4       NaN   16.62      10.84   6.49   3.71   5.78
# 13  26.74  ...    59.19       NaN   52.09      37.62  26.36  15.64   22.7
# 14    NaN  ...    59.44       NaN   48.59      36.13  26.82  14.01  20.86
# 15    NaN  ...    42.78       NaN   27.56      21.31  10.79   5.82   5.91
# 16    NaN  ...    54.42       NaN   37.16      30.17  22.09  11.46  17.46
#
# 0  GIRO ATIVOS CAGR RECEITAS 5 ANOS CAGR LUCROS 5 ANOS
# 0         0.46                15.85              21.94
# 1         0.46                15.85              21.94
# 2          0.5                15.85              40.33
# 3         0.59                25.41              55.55
# 4         0.44                21.72                NaN
# 5          0.4                12.46                NaN
# 6         0.39                 5.79             194.87
# 7         0.33                 3.53              12.25
# 8         0.29                -1.21             -18.85
# 9         0.23                -1.27                NaN
# 10        0.27                11.24              -37.9
# 11        0.35                 7.55             -64.79
# 12        0.34                  NaN                NaN
# 13        0.42                  NaN                NaN
# 14        0.39                  NaN                NaN
# 15        0.27                  NaN                NaN
# 16        0.38                  NaN                NaN
#
# [17 rows x 31 columns]

# %%
#adicionando o ticker
df_transposed['Ticker'] = ticker

#seta o indice como o ticker e ano
#df_transposed = df_transposed.set_index(['Ticker','Ano'])

df_transposed
# Out:
# 0    Ano    D.Y     P/L PEG RATIO  P/VP EV/EBITDA EV/EBIT P/EBITDA  P/EBIT  \
# 0   2024  11.75    5.68      -0.1  1.42      4.04     5.0      3.4    4.21
# 1   2023   7.87    7.37     -0.13  1.84      5.05    6.25     4.42    5.47
# 2   2022   8.53    4.43       NaN  2.27      4.06    5.16      3.7     4.7
# 3   2021  18.79     3.3       NaN  2.08       2.7    2.91     2.63    2.83
# 4   2020   2.75    17.3       NaN  2.49      6.34    9.03     6.23    8.88
# 5   2019   2.65  -42.22       NaN  1.74     15.85  139.25    14.32  125.75
# 6   2018   3.86    10.5      0.23  1.58       NaN    7.11      NaN    6.24
# 7   2017   3.29   11.98      0.37  1.47       NaN    7.85      NaN    6.11
# 8   2016   0.65   10.12     -0.08  1.06       NaN   10.44      NaN     6.5
# 9   2015   7.49   -1.55       0.0  0.52       NaN   -5.83      NaN   -2.39
# 10  2014   8.63  123.17      0.17   0.8       NaN    8.81      NaN    5.64
# 11  2013   5.06     NaN    -16.84  1.29       NaN    7.42      NaN    5.73
# 12  2012   5.35   22.93     -0.31  1.51       NaN   18.25      NaN   14.96
# 13  2011   7.31     5.6       NaN  1.48       NaN    4.79      NaN    4.04
# 14  2010    NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 15  2009    NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 16  2008    NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
#
# 0     VPA  ... M. EBITDA M. EBIT M. LÍQUIDA    ROE    ROA   ROIC GIRO ATIVOS  \
# 0    41.9  ...     38.45   31.07      23.03  24.99  10.66  21.26        0.46
# 1    41.9  ...     38.45   31.07      23.03  24.99  10.66  21.26        0.46
# 2   39.15  ...     50.73   39.88      42.35  51.27  21.16  28.76         0.5
# 3   37.49  ...     51.84   48.15       41.3  63.01  24.29  42.35        0.59
# 4   35.16  ...     35.57   24.97      12.81  14.38   5.59  18.93        0.44
# 5   30.56  ...     13.24    1.51      -4.49  -4.13   -1.8  -0.12         0.4
# 6   32.25  ...       NaN    32.1      19.08  15.06   7.51  18.07        0.39
# 7   27.41  ...       NaN   31.82      16.24  12.26   5.37  13.45        0.33
# 8   24.26  ...       NaN   21.89      14.07  10.46   4.13   4.86        0.29
# 9   25.01  ...       NaN  -36.67     -56.64 -33.71 -12.79 -19.03        0.23
# 10  27.29  ...       NaN   25.21       1.16   0.65   0.31   7.59        0.27
# 11  27.65  ...       NaN   32.95       0.11   0.08   0.04   8.23        0.35
# 12  27.93  ...       NaN   16.62      10.84   6.49   3.71   5.78        0.34
# 13  26.74  ...       NaN   52.09      37.62  26.36  15.64   22.7        0.42
# 14    NaN  ...       NaN   48.59      36.13  26.82  14.01  20.86        0.39
# 15    NaN  ...       NaN   27.56      21.31  10.79   5.82   5.91        0.27
# 16    NaN  ...       NaN   37.16      30.17  22.09  11.46  17.46        0.38
#
# 0  CAGR RECEITAS 5 ANOS CAGR LUCROS 5 ANOS Ticker
# 0                 15.85              21.94  VALE3
# 1                 15.85              21.94  VALE3
# 2                 15.85              40.33  VALE3
# 3                 25.41              55.55  VALE3
# 4                 21.72                NaN  VALE3
# 5                 12.46                NaN  VALE3
# 6                  5.79             194.87  VALE3
# 7                  3.53              12.25  VALE3
# 8                 -1.21             -18.85  VALE3
# 9                 -1.27                NaN  VALE3
# 10                11.24              -37.9  VALE3
# 11                 7.55             -64.79  VALE3
# 12                  NaN                NaN  VALE3
# 13                  NaN                NaN  VALE3
# 14                  NaN                NaN  VALE3
# 15                  NaN                NaN  VALE3
# 16                  NaN                NaN  VALE3
#
# [17 rows x 32 columns]

# %%
df_transposed['D.Y'] = df_transposed['D.Y'].astype(float).fillna(0)

# %%
# Aplicar a função para cada linha (ano) do DataFrame
df_transposed['PrecoAnoSeguinte'] = df_transposed['Ano'].astype(int).apply(lambda x: close_price_mean_for_year(precos_df, x + 1))
df_transposed['PrecoAnoAtual'] = df_transposed['Ano'].astype(int).apply(lambda x: close_price_mean_for_year(precos_df, x))

# %%
df_transposed
# Out:
# 0    Ano    D.Y     P/L PEG RATIO  P/VP EV/EBITDA EV/EBIT P/EBITDA  P/EBIT  \
# 0   2024  11.75    5.68      -0.1  1.42      4.04     5.0      3.4    4.21
# 1   2023   7.87    7.37     -0.13  1.84      5.05    6.25     4.42    5.47
# 2   2022   8.53    4.43       NaN  2.27      4.06    5.16      3.7     4.7
# 3   2021  18.79     3.3       NaN  2.08       2.7    2.91     2.63    2.83
# 4   2020   2.75    17.3       NaN  2.49      6.34    9.03     6.23    8.88
# 5   2019   2.65  -42.22       NaN  1.74     15.85  139.25    14.32  125.75
# 6   2018   3.86    10.5      0.23  1.58       NaN    7.11      NaN    6.24
# 7   2017   3.29   11.98      0.37  1.47       NaN    7.85      NaN    6.11
# 8   2016   0.65   10.12     -0.08  1.06       NaN   10.44      NaN     6.5
# 9   2015   7.49   -1.55       0.0  0.52       NaN   -5.83      NaN   -2.39
# 10  2014   8.63  123.17      0.17   0.8       NaN    8.81      NaN    5.64
# 11  2013   5.06     NaN    -16.84  1.29       NaN    7.42      NaN    5.73
# 12  2012   5.35   22.93     -0.31  1.51       NaN   18.25      NaN   14.96
# 13  2011   7.31     5.6       NaN  1.48       NaN    4.79      NaN    4.04
# 14  2010   0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 15  2009   0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 16  2008   0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
#
# 0     VPA  ... M. LÍQUIDA    ROE    ROA   ROIC GIRO ATIVOS  \
# 0    41.9  ...      23.03  24.99  10.66  21.26        0.46
# 1    41.9  ...      23.03  24.99  10.66  21.26        0.46
# 2   39.15  ...      42.35  51.27  21.16  28.76         0.5
# 3   37.49  ...       41.3  63.01  24.29  42.35        0.59
# 4   35.16  ...      12.81  14.38   5.59  18.93        0.44
# 5   30.56  ...      -4.49  -4.13   -1.8  -0.12         0.4
# 6   32.25  ...      19.08  15.06   7.51  18.07        0.39
# 7   27.41  ...      16.24  12.26   5.37  13.45        0.33
# 8   24.26  ...      14.07  10.46   4.13   4.86        0.29
# 9   25.01  ...     -56.64 -33.71 -12.79 -19.03        0.23
# 10  27.29  ...       1.16   0.65   0.31   7.59        0.27
# 11  27.65  ...       0.11   0.08   0.04   8.23        0.35
# 12  27.93  ...      10.84   6.49   3.71   5.78        0.34
# 13  26.74  ...      37.62  26.36  15.64   22.7        0.42
# 14    NaN  ...      36.13  26.82  14.01  20.86        0.39
# 15    NaN  ...      21.31  10.79   5.82   5.91        0.27
# 16    NaN  ...      30.17  22.09  11.46  17.46        0.38
#
# 0  CAGR RECEITAS 5 ANOS CAGR LUCROS 5 ANOS Ticker PrecoAnoSeguinte  \
# 0                 15.85              21.94  VALE3              NaN
# 1                 15.85              21.94  VALE3              NaN
# 2                 15.85              40.33  VALE3        73.996923
# 3                 25.41              55.55  VALE3        80.667885
# 4                 21.72                NaN  VALE3        94.930192
# 5                 12.46                NaN  VALE3        57.694231
# 6                  5.79             194.87  VALE3        49.491346
# 7                  3.53              12.25  VALE3        49.973774
# 8                 -1.21             -18.85  VALE3        31.257884
# 9                 -1.27                NaN  VALE3        17.637308
# 10                11.24              -37.9  VALE3        18.495000
# 11                 7.55             -64.79  VALE3        28.890577
# 12                  NaN                NaN  VALE3        34.654231
# 13                  NaN                NaN  VALE3        39.638679
# 14                  NaN                NaN  VALE3        48.555769
# 15                  NaN                NaN  VALE3        51.511538
# 16                  NaN                NaN  VALE3        38.541154
#
# 0  PrecoAnoAtual
# 0            NaN
# 1      73.996923
# 2      80.667885
# 3      94.930192
# 4      57.694231
# 5      49.491346
# 6      49.973774
# 7      31.257884
# 8      17.637308
# 9      18.495000
# 10     28.890577
# 11     34.654231
# 12     39.638679
# 13     48.555769
# 14     51.511538
# 15     38.541154
# 16     46.859615
#
# [17 rows x 34 columns]

# %%
# Criar o campo alvo
df_transposed['Alvo'] = np.where(df_transposed['PrecoAnoSeguinte'] > df_transposed['PrecoAnoAtual'] * 1.15, 'Barata',
                        np.where(df_transposed['PrecoAnoSeguinte'] < df_transposed['PrecoAnoAtual'] * 0.85, 'Cara', 'Neutra'))

# %%
df_transposed
# Out:
# 0    Ano    D.Y     P/L PEG RATIO  P/VP EV/EBITDA EV/EBIT P/EBITDA  P/EBIT  \
# 0   2024  11.75    5.68      -0.1  1.42      4.04     5.0      3.4    4.21
# 1   2023   7.87    7.37     -0.13  1.84      5.05    6.25     4.42    5.47
# 2   2022   8.53    4.43       NaN  2.27      4.06    5.16      3.7     4.7
# 3   2021  18.79     3.3       NaN  2.08       2.7    2.91     2.63    2.83
# 4   2020   2.75    17.3       NaN  2.49      6.34    9.03     6.23    8.88
# 5   2019   2.65  -42.22       NaN  1.74     15.85  139.25    14.32  125.75
# 6   2018   3.86    10.5      0.23  1.58       NaN    7.11      NaN    6.24
# 7   2017   3.29   11.98      0.37  1.47       NaN    7.85      NaN    6.11
# 8   2016   0.65   10.12     -0.08  1.06       NaN   10.44      NaN     6.5
# 9   2015   7.49   -1.55       0.0  0.52       NaN   -5.83      NaN   -2.39
# 10  2014   8.63  123.17      0.17   0.8       NaN    8.81      NaN    5.64
# 11  2013   5.06     NaN    -16.84  1.29       NaN    7.42      NaN    5.73
# 12  2012   5.35   22.93     -0.31  1.51       NaN   18.25      NaN   14.96
# 13  2011   7.31     5.6       NaN  1.48       NaN    4.79      NaN    4.04
# 14  2010   0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 15  2009   0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 16  2008   0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
#
# 0     VPA  ...    ROE    ROA   ROIC GIRO ATIVOS CAGR RECEITAS 5 ANOS  \
# 0    41.9  ...  24.99  10.66  21.26        0.46                15.85
# 1    41.9  ...  24.99  10.66  21.26        0.46                15.85
# 2   39.15  ...  51.27  21.16  28.76         0.5                15.85
# 3   37.49  ...  63.01  24.29  42.35        0.59                25.41
# 4   35.16  ...  14.38   5.59  18.93        0.44                21.72
# 5   30.56  ...  -4.13   -1.8  -0.12         0.4                12.46
# 6   32.25  ...  15.06   7.51  18.07        0.39                 5.79
# 7   27.41  ...  12.26   5.37  13.45        0.33                 3.53
# 8   24.26  ...  10.46   4.13   4.86        0.29                -1.21
# 9   25.01  ... -33.71 -12.79 -19.03        0.23                -1.27
# 10  27.29  ...   0.65   0.31   7.59        0.27                11.24
# 11  27.65  ...   0.08   0.04   8.23        0.35                 7.55
# 12  27.93  ...   6.49   3.71   5.78        0.34                  NaN
# 13  26.74  ...  26.36  15.64   22.7        0.42                  NaN
# 14    NaN  ...  26.82  14.01  20.86        0.39                  NaN
# 15    NaN  ...  10.79   5.82   5.91        0.27                  NaN
# 16    NaN  ...  22.09  11.46  17.46        0.38                  NaN
#
# 0  CAGR LUCROS 5 ANOS Ticker PrecoAnoSeguinte PrecoAnoAtual    Alvo
# 0               21.94  VALE3              NaN           NaN  Neutra
# 1               21.94  VALE3              NaN     73.996923  Neutra
# 2               40.33  VALE3        73.996923     80.667885  Neutra
# 3               55.55  VALE3        80.667885     94.930192    Cara
# 4                 NaN  VALE3        94.930192     57.694231  Barata
# 5                 NaN  VALE3        57.694231     49.491346  Barata
# 6              194.87  VALE3        49.491346     49.973774  Neutra
# 7               12.25  VALE3        49.973774     31.257884  Barata
# 8              -18.85  VALE3        31.257884     17.637308  Barata
# 9                 NaN  VALE3        17.637308     18.495000  Neutra
# 10              -37.9  VALE3        18.495000     28.890577    Cara
# 11             -64.79  VALE3        28.890577     34.654231    Cara
# 12                NaN  VALE3        34.654231     39.638679  Neutra
# 13                NaN  VALE3        39.638679     48.555769    Cara
# 14                NaN  VALE3        48.555769     51.511538  Neutra
# 15                NaN  VALE3        51.511538     38.541154  Barata
# 16                NaN  VALE3        38.541154     46.859615    Cara
#
# [17 rows x 35 columns]

# %%
# Verificar se o diretório existe, caso contrário, criar
output_dir = '../../data/processed'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Salvar o DataFrame em um arquivo parquet
output_file = os.path.join(output_dir, f'dados_{ticker}.parquet')
df_transposed.to_parquet(output_file)
