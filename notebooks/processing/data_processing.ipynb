# %%
# Importar bibliotecas
import pandas as pd
import numpy as np
import yfinance as yf
import os

start_date = '2007-01-01'
end_date = '2024-01-01'
ticker = "AMER3"

# Carregar dados
data = pd.read_csv(f"../../data/raw/indicadores_{ticker}.csv")

# Baixar os dados do Yahoo Finance
precos = yf.download((ticker+'.SA'), start=start_date, end=end_date, interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BIDI11.SA']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %%
data.head()
# Out:
#           Tipo do Indicador Nome do Indicador    ATUAL     2023 2022     2021  \
# 0  INDICADORES DE VALUATION               D.Y       -%       -%   -%    0,27%
# 1  INDICADORES DE VALUATION               P/L  -238,07  -238,07    -  -337,96
# 2  INDICADORES DE VALUATION         PEG RATIO     0,13     0,13    -        -
# 3  INDICADORES DE VALUATION              P/VP     1,08     1,08    -     2,93
# 4  INDICADORES DE VALUATION         EV/EBITDA        -        -    -  -155,95
#
#         2020   2019 2018 2017 2016 2015
# 0      0,17%  0,23%   -%   -%   -%   -%
# 1  -3.485,69  20,00    -    -    -    -
# 2          -      -    -    -    -    -
# 3       7,60   0,72    -    -    -    -
# 4    -792,22  17,89    -    -    -    -

# %%
precos_df = pd.DataFrame(precos)

precos_df.head()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# Função para calcular a média do preço de fechamento para um determinado ano
def close_price_mean_for_year(df, year):
    df_year = df[df.index.year == year]
    return df_year['Close'].mean()

# %%
# Remover a coluna "Tipo do Indicador"
data = data.drop('Tipo do Indicador', axis=1)

# Renomear a coluna "ATUAL" para "2024"
data = data.rename(columns={'ATUAL': '2024'})

# %%
df = pd.DataFrame(data)

# Remover caracteres especiais e ajustar o separador decimal
for col in df.columns[1:]:
    df[col] = df[col].str.replace(",", ".").str.rstrip("%")


# Substituir '-' por NaN em todas as colunas exceto as duas primeiras
df.iloc[:, 1:] = df.iloc[:, 1:].replace('-', np.nan)

# %%
# Converter as colunas para tipo numérico
for col in df.columns[1:]:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df.head()
# Out:
#   Nome do Indicador  2024  2023  2022  2021    2020   2019   2018   2017  \
# 0               D.Y   NaN   NaN  6.43   NaN     NaN    NaN    NaN    NaN
# 1               P/L -0.04 -0.06 -0.67 -4.58 -200.85 -90.32 -47.97 -22.54
# 2         PEG RATIO  0.00  0.00   NaN   NaN     NaN    NaN  14.08   1.47
# 3              P/VP -0.02 -0.03 -0.33  1.79    4.46   5.01   5.39   2.37
# 4         EV/EBITDA -2.77 -2.82 -4.09 -7.52   44.99  45.54  50.62  31.93
#
#    2016  2015   2014   2013   2012   2011  2010  2009
# 0   NaN   NaN    NaN    NaN    NaN   0.62   NaN   NaN
# 1 -5.40 -9.30 -21.85 -14.98 -15.92 -11.46   NaN   NaN
# 2 -0.33 -0.06  -9.29   2.30  -0.17    NaN   NaN   NaN
# 3  0.85  1.44   1.16   2.88   2.80   0.90   NaN   NaN
# 4  7.54  8.47   7.68  10.88  16.15   7.10   NaN   NaN

# %%
# Transpor o DataFrame
df_transposed = df.transpose()

# Resetar o índice
df_transposed = df_transposed.reset_index()


# Definir a primeira linha como o cabeçalho
df_transposed.columns = df_transposed.iloc[0]

# Remover a primeira linha do DataFrame
df_transposed = df_transposed[1:]

# Resetar o índice
df_transposed = df_transposed.reset_index(drop=True)

#Troca o nome da coluna Nome do Indicador para Ano
df_transposed = df_transposed.rename(columns={'Nome do Indicador': 'Ano'})

df_transposed
# Out:
# 0    Ano   D.Y     P/L PEG RATIO  P/VP EV/EBITDA EV/EBIT P/EBITDA  P/EBIT  \
# 0   2024   NaN   -0.04       0.0 -0.02     -2.77    -2.2    -0.08   -0.06
# 1   2023   NaN   -0.06       0.0 -0.03     -2.82   -2.24    -0.13   -0.11
# 2   2022  6.43   -0.67       NaN -0.33     -4.09   -3.25     -1.4   -1.11
# 3   2021   NaN   -4.58       NaN  1.79     -7.52   -5.63     -8.5   -6.36
# 4   2020   NaN -200.85       NaN  4.46     44.99  216.24    48.77  234.43
# 5   2019   NaN  -90.32       NaN  5.01     45.54  276.83    45.62  277.31
# 6   2018   NaN  -47.97     14.08  5.39     50.62 -913.96    46.24 -834.81
# 7   2017   NaN  -22.54      1.47  2.37     31.93     NaN    26.78  843.53
# 8   2016   NaN    -5.4     -0.33  0.85      7.54   13.64     4.02    7.27
# 9   2015   NaN    -9.3     -0.06  1.44      8.47    13.4     5.97    9.44
# 10  2014   NaN  -21.85     -9.29  1.16      7.68   10.82     6.91    9.73
# 11  2013   NaN  -14.98       2.3  2.88     10.88   14.99     6.36    8.76
# 12  2012   NaN  -15.92     -0.17   2.8     16.15   25.68    10.69    17.0
# 13  2011  0.62  -11.46       NaN   0.9       7.1    9.27      3.3    4.32
# 14  2010   NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 15  2009   NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
#
# 0     VPA  ... M. BRUTA M. EBITDA M. EBIT M. LÍQUIDA     ROE    ROA    ROIC  \
# 0  -29.55  ...    19.46    -24.06  -30.26     -50.03  -48.42 -41.26  202.73
# 1  -29.55  ...    19.46    -24.06  -30.26     -50.03  -48.42 -41.26  202.73
# 2  -29.56  ...    19.46    -24.06  -30.26     -50.03  -48.42 -41.26  202.73
# 3   17.61  ...    17.28    -14.91  -19.94      -27.7 -148.26 -14.01 -130.72
# 4   16.94  ...    28.42      8.57    1.78      -2.08   -2.22  -0.93    0.82
# 5   12.54  ...    29.72      9.31    1.53       -4.7   -5.55  -1.98   -0.34
# 6     7.8  ...    25.81      6.35   -0.35      -6.13  -11.24  -3.05   -2.06
# 7    8.63  ...    21.14      5.51    0.17      -6.55  -10.53  -3.26   -1.95
# 8   11.96  ...    19.91      7.59     4.2      -5.65  -15.79  -4.74    1.69
# 9   10.59  ...    19.83      7.23    4.57      -4.64  -15.46  -4.21    5.79
# 10  19.37  ...    24.22      6.48     4.6      -2.05    -5.3  -2.14    4.93
# 11    5.3  ...    24.76      6.18    4.48      -2.62  -19.23  -2.41    4.37
# 12   6.06  ...     23.8      5.28    3.32      -3.55  -17.61  -3.57    1.88
# 13  10.03  ...    25.04      7.31    5.59      -2.11   -7.83  -2.18    5.86
# 14    NaN  ...    27.89     11.45   10.08       0.82   14.87   1.05   17.12
# 15    NaN  ...    29.25       NaN   10.34       1.71   32.15   2.68   20.53
#
# 0  GIRO ATIVOS CAGR RECEITAS 5 ANOS CAGR LUCROS 5 ANOS
# 0         0.82                32.64                NaN
# 1         0.82                32.64                NaN
# 2         0.82                32.64                NaN
# 3         0.51                21.23                NaN
# 4         0.45                 2.35                NaN
# 5         0.42                 -3.2                NaN
# 6          0.5                 1.28                NaN
# 7          0.5                 5.49                NaN
# 8         0.84                15.24                NaN
# 9         0.91                17.22                NaN
# 10        1.04                 17.0                NaN
# 11        0.92                  NaN                NaN
# 12        1.01                  NaN                NaN
# 13        1.03                  NaN                NaN
# 14        1.27                  NaN                NaN
# 15        1.57                  NaN                NaN
#
# [16 rows x 31 columns]

# %%
#adicionando o ticker
df_transposed['Ticker'] = ticker

#seta o indice como o ticker e ano
#df_transposed = df_transposed.set_index(['Ticker','Ano'])

df_transposed
# Out:
# 0    Ano   D.Y     P/L PEG RATIO  P/VP EV/EBITDA EV/EBIT P/EBITDA  P/EBIT  \
# 0   2024   NaN   -0.04       0.0 -0.02     -2.77    -2.2    -0.08   -0.06
# 1   2023   NaN   -0.06       0.0 -0.03     -2.82   -2.24    -0.13   -0.11
# 2   2022  6.43   -0.67       NaN -0.33     -4.09   -3.25     -1.4   -1.11
# 3   2021   NaN   -4.58       NaN  1.79     -7.52   -5.63     -8.5   -6.36
# 4   2020   NaN -200.85       NaN  4.46     44.99  216.24    48.77  234.43
# 5   2019   NaN  -90.32       NaN  5.01     45.54  276.83    45.62  277.31
# 6   2018   NaN  -47.97     14.08  5.39     50.62 -913.96    46.24 -834.81
# 7   2017   NaN  -22.54      1.47  2.37     31.93     NaN    26.78  843.53
# 8   2016   NaN    -5.4     -0.33  0.85      7.54   13.64     4.02    7.27
# 9   2015   NaN    -9.3     -0.06  1.44      8.47    13.4     5.97    9.44
# 10  2014   NaN  -21.85     -9.29  1.16      7.68   10.82     6.91    9.73
# 11  2013   NaN  -14.98       2.3  2.88     10.88   14.99     6.36    8.76
# 12  2012   NaN  -15.92     -0.17   2.8     16.15   25.68    10.69    17.0
# 13  2011  0.62  -11.46       NaN   0.9       7.1    9.27      3.3    4.32
# 14  2010   NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 15  2009   NaN     NaN       NaN   NaN       NaN     NaN      NaN     NaN
#
# 0     VPA  ... M. EBITDA M. EBIT M. LÍQUIDA     ROE    ROA    ROIC  \
# 0  -29.55  ...    -24.06  -30.26     -50.03  -48.42 -41.26  202.73
# 1  -29.55  ...    -24.06  -30.26     -50.03  -48.42 -41.26  202.73
# 2  -29.56  ...    -24.06  -30.26     -50.03  -48.42 -41.26  202.73
# 3   17.61  ...    -14.91  -19.94      -27.7 -148.26 -14.01 -130.72
# 4   16.94  ...      8.57    1.78      -2.08   -2.22  -0.93    0.82
# 5   12.54  ...      9.31    1.53       -4.7   -5.55  -1.98   -0.34
# 6     7.8  ...      6.35   -0.35      -6.13  -11.24  -3.05   -2.06
# 7    8.63  ...      5.51    0.17      -6.55  -10.53  -3.26   -1.95
# 8   11.96  ...      7.59     4.2      -5.65  -15.79  -4.74    1.69
# 9   10.59  ...      7.23    4.57      -4.64  -15.46  -4.21    5.79
# 10  19.37  ...      6.48     4.6      -2.05    -5.3  -2.14    4.93
# 11    5.3  ...      6.18    4.48      -2.62  -19.23  -2.41    4.37
# 12   6.06  ...      5.28    3.32      -3.55  -17.61  -3.57    1.88
# 13  10.03  ...      7.31    5.59      -2.11   -7.83  -2.18    5.86
# 14    NaN  ...     11.45   10.08       0.82   14.87   1.05   17.12
# 15    NaN  ...       NaN   10.34       1.71   32.15   2.68   20.53
#
# 0  GIRO ATIVOS CAGR RECEITAS 5 ANOS CAGR LUCROS 5 ANOS Ticker
# 0         0.82                32.64                NaN  AMER3
# 1         0.82                32.64                NaN  AMER3
# 2         0.82                32.64                NaN  AMER3
# 3         0.51                21.23                NaN  AMER3
# 4         0.45                 2.35                NaN  AMER3
# 5         0.42                 -3.2                NaN  AMER3
# 6          0.5                 1.28                NaN  AMER3
# 7          0.5                 5.49                NaN  AMER3
# 8         0.84                15.24                NaN  AMER3
# 9         0.91                17.22                NaN  AMER3
# 10        1.04                 17.0                NaN  AMER3
# 11        0.92                  NaN                NaN  AMER3
# 12        1.01                  NaN                NaN  AMER3
# 13        1.03                  NaN                NaN  AMER3
# 14        1.27                  NaN                NaN  AMER3
# 15        1.57                  NaN                NaN  AMER3
#
# [16 rows x 32 columns]

# %%
df_transposed['D.Y'] = df_transposed['D.Y'].astype(float).fillna(0)

# %%
# Aplicar a função para cada linha (ano) do DataFrame
df_transposed['PrecoAnoSeguinte'] = df_transposed['Ano'].astype(int).apply(lambda x: close_price_mean_for_year(precos_df, x + 1))
df_transposed['PrecoAnoAtual'] = df_transposed['Ano'].astype(int).apply(lambda x: close_price_mean_for_year(precos_df, x))

# %%
df_transposed
# Out:
# 0    Ano   D.Y     P/L PEG RATIO  P/VP EV/EBITDA EV/EBIT P/EBITDA  P/EBIT  \
# 0   2024  0.00   -0.04       0.0 -0.02     -2.77    -2.2    -0.08   -0.06
# 1   2023  0.00   -0.06       0.0 -0.03     -2.82   -2.24    -0.13   -0.11
# 2   2022  6.43   -0.67       NaN -0.33     -4.09   -3.25     -1.4   -1.11
# 3   2021  0.00   -4.58       NaN  1.79     -7.52   -5.63     -8.5   -6.36
# 4   2020  0.00 -200.85       NaN  4.46     44.99  216.24    48.77  234.43
# 5   2019  0.00  -90.32       NaN  5.01     45.54  276.83    45.62  277.31
# 6   2018  0.00  -47.97     14.08  5.39     50.62 -913.96    46.24 -834.81
# 7   2017  0.00  -22.54      1.47  2.37     31.93     NaN    26.78  843.53
# 8   2016  0.00    -5.4     -0.33  0.85      7.54   13.64     4.02    7.27
# 9   2015  0.00    -9.3     -0.06  1.44      8.47    13.4     5.97    9.44
# 10  2014  0.00  -21.85     -9.29  1.16      7.68   10.82     6.91    9.73
# 11  2013  0.00  -14.98       2.3  2.88     10.88   14.99     6.36    8.76
# 12  2012  0.00  -15.92     -0.17   2.8     16.15   25.68    10.69    17.0
# 13  2011  0.62  -11.46       NaN   0.9       7.1    9.27      3.3    4.32
# 14  2010  0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 15  2009  0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
#
# 0     VPA  ... M. LÍQUIDA     ROE    ROA    ROIC GIRO ATIVOS  \
# 0  -29.55  ...     -50.03  -48.42 -41.26  202.73        0.82
# 1  -29.55  ...     -50.03  -48.42 -41.26  202.73        0.82
# 2  -29.56  ...     -50.03  -48.42 -41.26  202.73        0.82
# 3   17.61  ...      -27.7 -148.26 -14.01 -130.72        0.51
# 4   16.94  ...      -2.08   -2.22  -0.93    0.82        0.45
# 5   12.54  ...       -4.7   -5.55  -1.98   -0.34        0.42
# 6     7.8  ...      -6.13  -11.24  -3.05   -2.06         0.5
# 7    8.63  ...      -6.55  -10.53  -3.26   -1.95         0.5
# 8   11.96  ...      -5.65  -15.79  -4.74    1.69        0.84
# 9   10.59  ...      -4.64  -15.46  -4.21    5.79        0.91
# 10  19.37  ...      -2.05    -5.3  -2.14    4.93        1.04
# 11    5.3  ...      -2.62  -19.23  -2.41    4.37        0.92
# 12   6.06  ...      -3.55  -17.61  -3.57    1.88        1.01
# 13  10.03  ...      -2.11   -7.83  -2.18    5.86        1.03
# 14    NaN  ...       0.82   14.87   1.05   17.12        1.27
# 15    NaN  ...       1.71   32.15   2.68   20.53        1.57
#
# 0  CAGR RECEITAS 5 ANOS CAGR LUCROS 5 ANOS Ticker PrecoAnoSeguinte  \
# 0                 32.64                NaN  AMER3              NaN
# 1                 32.64                NaN  AMER3              NaN
# 2                 32.64                NaN  AMER3         1.239423
# 3                 21.23                NaN  AMER3        19.961902
# 4                  2.35                NaN  AMER3        54.292429
# 5                  -3.2                NaN  AMER3        83.763484
# 6                  1.28                NaN  AMER3        44.422621
# 7                  5.49                NaN  AMER3        27.896747
# 8                 15.24                NaN  AMER3        14.912225
# 9                 17.22                NaN  AMER3        12.437000
# 10                 17.0                NaN  AMER3        18.472331
# 11                  NaN                NaN  AMER3        26.309320
# 12                  NaN                NaN  AMER3        11.963232
# 13                  NaN                NaN  AMER3         8.457504
# 14                  NaN                NaN  AMER3        16.617233
# 15                  NaN                NaN  AMER3        29.564516
#
# 0  PrecoAnoAtual
# 0            NaN
# 1       1.239423
# 2      19.961902
# 3      54.292429
# 4      83.763484
# 5      44.422621
# 6      27.896747
# 7      14.912225
# 8      12.437000
# 9      18.472331
# 10     26.309320
# 11     11.963232
# 12      8.457504
# 13     16.617233
# 14     29.564516
# 15     33.418928
#
# [16 rows x 34 columns]

# %%
# Criar o campo alvo
df_transposed['Alvo'] = np.where(df_transposed['PrecoAnoSeguinte'] > df_transposed['PrecoAnoAtual'] * 1.15, 'Barata',
                        np.where(df_transposed['PrecoAnoSeguinte'] < df_transposed['PrecoAnoAtual'] * 0.85, 'Cara', 'Neutra'))

# %%
df_transposed
# Out:
# 0    Ano   D.Y     P/L PEG RATIO  P/VP EV/EBITDA EV/EBIT P/EBITDA  P/EBIT  \
# 0   2024  0.00   -0.04       0.0 -0.02     -2.77    -2.2    -0.08   -0.06
# 1   2023  0.00   -0.06       0.0 -0.03     -2.82   -2.24    -0.13   -0.11
# 2   2022  6.43   -0.67       NaN -0.33     -4.09   -3.25     -1.4   -1.11
# 3   2021  0.00   -4.58       NaN  1.79     -7.52   -5.63     -8.5   -6.36
# 4   2020  0.00 -200.85       NaN  4.46     44.99  216.24    48.77  234.43
# 5   2019  0.00  -90.32       NaN  5.01     45.54  276.83    45.62  277.31
# 6   2018  0.00  -47.97     14.08  5.39     50.62 -913.96    46.24 -834.81
# 7   2017  0.00  -22.54      1.47  2.37     31.93     NaN    26.78  843.53
# 8   2016  0.00    -5.4     -0.33  0.85      7.54   13.64     4.02    7.27
# 9   2015  0.00    -9.3     -0.06  1.44      8.47    13.4     5.97    9.44
# 10  2014  0.00  -21.85     -9.29  1.16      7.68   10.82     6.91    9.73
# 11  2013  0.00  -14.98       2.3  2.88     10.88   14.99     6.36    8.76
# 12  2012  0.00  -15.92     -0.17   2.8     16.15   25.68    10.69    17.0
# 13  2011  0.62  -11.46       NaN   0.9       7.1    9.27      3.3    4.32
# 14  2010  0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
# 15  2009  0.00     NaN       NaN   NaN       NaN     NaN      NaN     NaN
#
# 0     VPA  ...     ROE    ROA    ROIC GIRO ATIVOS CAGR RECEITAS 5 ANOS  \
# 0  -29.55  ...  -48.42 -41.26  202.73        0.82                32.64
# 1  -29.55  ...  -48.42 -41.26  202.73        0.82                32.64
# 2  -29.56  ...  -48.42 -41.26  202.73        0.82                32.64
# 3   17.61  ... -148.26 -14.01 -130.72        0.51                21.23
# 4   16.94  ...   -2.22  -0.93    0.82        0.45                 2.35
# 5   12.54  ...   -5.55  -1.98   -0.34        0.42                 -3.2
# 6     7.8  ...  -11.24  -3.05   -2.06         0.5                 1.28
# 7    8.63  ...  -10.53  -3.26   -1.95         0.5                 5.49
# 8   11.96  ...  -15.79  -4.74    1.69        0.84                15.24
# 9   10.59  ...  -15.46  -4.21    5.79        0.91                17.22
# 10  19.37  ...    -5.3  -2.14    4.93        1.04                 17.0
# 11    5.3  ...  -19.23  -2.41    4.37        0.92                  NaN
# 12   6.06  ...  -17.61  -3.57    1.88        1.01                  NaN
# 13  10.03  ...   -7.83  -2.18    5.86        1.03                  NaN
# 14    NaN  ...   14.87   1.05   17.12        1.27                  NaN
# 15    NaN  ...   32.15   2.68   20.53        1.57                  NaN
#
# 0  CAGR LUCROS 5 ANOS Ticker PrecoAnoSeguinte PrecoAnoAtual    Alvo
# 0                 NaN  AMER3              NaN           NaN  Neutra
# 1                 NaN  AMER3              NaN      1.239423  Neutra
# 2                 NaN  AMER3         1.239423     19.961902    Cara
# 3                 NaN  AMER3        19.961902     54.292429    Cara
# 4                 NaN  AMER3        54.292429     83.763484    Cara
# 5                 NaN  AMER3        83.763484     44.422621  Barata
# 6                 NaN  AMER3        44.422621     27.896747  Barata
# 7                 NaN  AMER3        27.896747     14.912225  Barata
# 8                 NaN  AMER3        14.912225     12.437000  Barata
# 9                 NaN  AMER3        12.437000     18.472331    Cara
# 10                NaN  AMER3        18.472331     26.309320    Cara
# 11                NaN  AMER3        26.309320     11.963232  Barata
# 12                NaN  AMER3        11.963232      8.457504  Barata
# 13                NaN  AMER3         8.457504     16.617233    Cara
# 14                NaN  AMER3        16.617233     29.564516    Cara
# 15                NaN  AMER3        29.564516     33.418928  Neutra
#
# [16 rows x 35 columns]

# %%
# Verificar se o diretório existe, caso contrário, criar
output_dir = '../../data/processed'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Salvar o DataFrame em um arquivo parquet
output_file = os.path.join(output_dir, f'dados_{ticker}.parquet')
df_transposed.to_parquet(output_file)
